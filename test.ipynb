# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('transactiondata.xlsx')
df.head(100)
# Out:
#    Family ID       Member ID Transaction Date    Category  Amount  Income  \
# 0     FAM001  FAM001_Member1       2024-10-07      Travel  409.12  113810
# 1     FAM001  FAM001_Member1       2024-10-16      Travel  270.91  113810
# 2     FAM001  FAM001_Member1       2024-10-17   Groceries   91.10  113810
# 3     FAM001  FAM001_Member1       2024-10-25  Healthcare  198.23  113810
# 4     FAM001  FAM001_Member1       2024-10-25   Education  206.42  113810
# ..       ...             ...              ...         ...     ...     ...
# 95    FAM002  FAM002_Member1       2024-10-18        Food  122.76   44592
# 96    FAM002  FAM002_Member1       2024-10-03  Healthcare  360.31   44592
# 97    FAM002  FAM002_Member1       2024-10-17  Healthcare  390.53   44592
# 98    FAM002  FAM002_Member1       2024-10-26      Travel  117.47   44592
# 99    FAM002  FAM002_Member1       2024-10-03   Utilities  187.24   44592
#
#     Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# 0     20234              5781           2422                  2959
# 1     20234              5781           2422                  2959
# 2     20234              5781           2422                  2959
# 3     20234              5781           2422                  2959
# 4     20234              5781           2422                  2959
# ..      ...               ...            ...                   ...
# 95    29492              5630           4541                   995
# 96    29492              5630           4541                   995
# 97    29492              5630           4541                   995
# 98    29492              5630           4541                   995
# 99    29492              5630           4541                   995
#
#     Dependents  Financial Goals Met (%)
# 0            2                       68
# 1            2                       68
# 2            2                       68
# 3            2                       68
# 4            2                       68
# ..         ...                      ...
# 95           3                       60
# 96           3                       60
# 97           3                       60
# 98           3                       60
# 99           3                       60
#
# [100 rows x 12 columns]

# %%
df.describe(include='all')
# Out:
#        Family ID       Member ID               Transaction Date   Category  \
# count      16306           16306                          16306      16306
# unique       200             926                            NaN          7
# top       FAM194  FAM194_Member7                            NaN  Groceries
# freq         167              30                            NaN       2390
# mean         NaN             NaN  2024-10-16 00:34:31.777259776        NaN
# min          NaN             NaN            2024-10-01 00:00:00        NaN
# 25%          NaN             NaN            2024-10-08 00:00:00        NaN
# 50%          NaN             NaN            2024-10-16 00:00:00        NaN
# 75%          NaN             NaN            2024-10-24 00:00:00        NaN
# max          NaN             NaN            2024-10-31 00:00:00        NaN
# std          NaN             NaN                            NaN        NaN
#
#               Amount         Income       Savings  Monthly Expenses  \
# count   16306.000000   16306.000000  16306.000000      16306.000000
# unique           NaN            NaN           NaN               NaN
# top              NaN            NaN           NaN               NaN
# freq             NaN            NaN           NaN               NaN
# mean      256.368534   90340.503925  24473.998038       3948.522384
# min        10.030000   30851.000000   1037.000000       1013.000000
# 25%       134.820000   59871.000000  11016.000000       2582.000000
# 50%       256.055000   90142.000000  25504.000000       3721.000000
# 75%       379.240000  119733.000000  37422.000000       5450.000000
# max       499.910000  149871.000000  49217.000000       6968.000000
# std       141.153813   34740.834136  14828.955695       1689.987801
#
#         Loan Payments  Credit Card Spending    Dependents  \
# count    16306.000000          16306.000000  16306.000000
# unique            NaN                   NaN           NaN
# top               NaN                   NaN           NaN
# freq              NaN                   NaN           NaN
# mean      2529.978965           1782.880535      3.201521
# min          3.000000            510.000000      0.000000
# 25%       1390.000000           1221.000000      2.000000
# 50%       2548.000000           1705.000000      3.000000
# 75%       3724.000000           2422.000000      4.000000
# max       4974.000000           2999.000000      5.000000
# std       1384.105561            716.595101      1.468880
#
#         Financial Goals Met (%)
# count              16306.000000
# unique                      NaN
# top                         NaN
# freq                        NaN
# mean                  59.418006
# min                   21.000000
# 25%                   37.000000
# 50%                   58.000000
# 75%                   79.000000
# max                  100.000000
# std                   23.444304

# %%
df['Category'].unique()
# Out:
# array(['Travel', 'Groceries', 'Healthcare', 'Education', 'Utilities',
#        'Food', 'Entertainment'], dtype=object)

# %%
df.columns
# Out:
# Index(['Family ID', 'Member ID', 'Transaction Date', 'Category', 'Amount',
#        'Income', 'Savings', 'Monthly Expenses', 'Loan Payments',
#        'Credit Card Spending', 'Dependents', 'Financial Goals Met (%)'],
#       dtype='object')

# %%
# 926 ppl from 200 families, 7 categories of expenses
quant_values = df[['Income', 'Savings', 'Monthly Expenses', 'Loan Payments', 'Credit Card Spending', 'Dependents', 'Financial Goals Met (%)']]
quant_values.head(10)
# Out:
#    Income  Savings  Monthly Expenses  Loan Payments  Credit Card Spending  \
# 0  113810    20234              5781           2422                  2959
# 1  113810    20234              5781           2422                  2959
# 2  113810    20234              5781           2422                  2959
# 3  113810    20234              5781           2422                  2959
# 4  113810    20234              5781           2422                  2959
# 5  113810    20234              5781           2422                  2959
# 6  113810    20234              5781           2422                  2959
# 7  113810    20234              5781           2422                  2959
# 8  113810    20234              5781           2422                  2959
# 9  113810    20234              5781           2422                  2959
#
#    Dependents  Financial Goals Met (%)
# 0           2                       68
# 1           2                       68
# 2           2                       68
# 3           2                       68
# 4           2                       68
# 5           2                       68
# 6           2                       68
# 7           2                       68
# 8           2                       68
# 9           2                       68

# %%
quant_values.corr()
# Out:
#                            Income   Savings  Monthly Expenses  Loan Payments  \
# Income                   1.000000 -0.108340         -0.041355      -0.073053
# Savings                 -0.108340  1.000000         -0.082094      -0.125158
# Monthly Expenses        -0.041355 -0.082094          1.000000      -0.052883
# Loan Payments           -0.073053 -0.125158         -0.052883       1.000000
# Credit Card Spending    -0.123225  0.022499         -0.046059       0.025535
# Dependents               0.005717 -0.012153          0.028577      -0.019567
# Financial Goals Met (%) -0.094626 -0.090095          0.003698       0.034911
#
#                          Credit Card Spending  Dependents  \
# Income                              -0.123225    0.005717
# Savings                              0.022499   -0.012153
# Monthly Expenses                    -0.046059    0.028577
# Loan Payments                        0.025535   -0.019567
# Credit Card Spending                 1.000000   -0.033939
# Dependents                          -0.033939    1.000000
# Financial Goals Met (%)              0.010204   -0.027768
#
#                          Financial Goals Met (%)
# Income                                 -0.094626
# Savings                                -0.090095
# Monthly Expenses                        0.003698
# Loan Payments                           0.034911
# Credit Card Spending                    0.010204
# Dependents                             -0.027768
# Financial Goals Met (%)                 1.000000

# %%
#Absolutely no linear correlations
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.pairplot(quant_values)
plt.show()

# %%
#No major revelations here either
#perhaps family data summed
familydata = df[['Family ID','Amount']].groupby('Family ID').sum()
familydata
# Out:
#              Amount
# Family ID
# FAM001     23188.90
# FAM002     22309.71
# FAM003     11220.34
# FAM004     23483.10
# FAM005     40246.21
# ...             ...
# FAM196     31433.34
# FAM197      4032.82
# FAM198     19378.59
# FAM199     31009.65
# FAM200     24887.93
#
# [200 rows x 1 columns]

# %%
family_member_counts = df.groupby('Family ID')['Member ID'].nunique()
family_member_counts = family_member_counts.reset_index()
family_member_counts.columns = ['Family ID', 'Member Count']
family_member_counts
# Out:
#     Family ID  Member Count
# 0      FAM001             4
# 1      FAM002             5
# 2      FAM003             2
# 3      FAM004             5
# 4      FAM005             7
# ..        ...           ...
# 195    FAM196             7
# 196    FAM197             2
# 197    FAM198             4
# 198    FAM199             7
# 199    FAM200             6
#
# [200 rows x 2 columns]

# %%
goalpercentagedf = df[['Family ID','Income', 'Savings', 'Monthly Expenses', 'Loan Payments', 'Credit Card Spending','Financial Goals Met (%)']].drop_duplicates()
goalpercentagedf
# Out:
#       Family ID  Income  Savings  Monthly Expenses  Loan Payments  \
# 0        FAM001  113810    20234              5781           2422
# 93       FAM002   44592    29492              5630           4541
# 181      FAM003   33278    11365              5282           1042
# 228      FAM004  127196    30735              3591           1571
# 323      FAM005   66048     1212              3136           3444
# ...         ...     ...      ...               ...            ...
# 15866    FAM196   64973     3604              3533            622
# 15990    FAM197  130741    41591              6463           4850
# 16009    FAM198  114012     6372              4345           1989
# 16085    FAM199   74587    28474              3672            834
# 16202    FAM200   44621    44081              4296           2470
#
#        Credit Card Spending  Financial Goals Met (%)
# 0                      2959                       68
# 93                      995                       60
# 181                    2818                      100
# 228                     668                       82
# 323                    1922                       89
# ...                     ...                      ...
# 15866                   744                       26
# 15990                  1179                       62
# 16009                  1759                       51
# 16085                  2937                       36
# 16202                  2831                       92
#
# [200 rows x 7 columns]

# %%
familydata = familydata.merge(family_member_counts, how='right',on='Family ID')
familydata = familydata.merge(goalpercentagedf, how='right',on='Family ID')
familydata
# Out:
#     Family ID    Amount  Member Count  Income  Savings  Monthly Expenses  \
# 0      FAM001  23188.90             4  113810    20234              5781
# 1      FAM002  22309.71             5   44592    29492              5630
# 2      FAM003  11220.34             2   33278    11365              5282
# 3      FAM004  23483.10             5  127196    30735              3591
# 4      FAM005  40246.21             7   66048     1212              3136
# ..        ...       ...           ...     ...      ...               ...
# 195    FAM196  31433.34             7   64973     3604              3533
# 196    FAM197   4032.82             2  130741    41591              6463
# 197    FAM198  19378.59             4  114012     6372              4345
# 198    FAM199  31009.65             7   74587    28474              3672
# 199    FAM200  24887.93             6   44621    44081              4296
#
#      Loan Payments  Credit Card Spending  Financial Goals Met (%)
# 0             2422                  2959                       68
# 1             4541                   995                       60
# 2             1042                  2818                      100
# 3             1571                   668                       82
# 4             3444                  1922                       89
# ..             ...                   ...                      ...
# 195            622                   744                       26
# 196           4850                  1179                       62
# 197           1989                  1759                       51
# 198            834                  2937                       36
# 199           2470                  2831                       92
#
# [200 rows x 9 columns]

# %%
sns.pairplot(familydata)
plt.show()

# %%
corr = familydata[['Amount','Income','Savings','Monthly Expenses','Loan Payments','Credit Card Spending','Member Count','Financial Goals Met (%)']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
#so from graphs and corr matrix it's fairly obvious that there is a fairly strong linear relationship between amount, income and some corr bw amount expenses and spending
# Higher loan payments == lower savings and vice versa; more savings == less loan payments; more members == more spending
# Questions to still investigate:
# 1. What are the outliers and do they carry a message? can they just be removed?

# %%
#Building Financial scoring model factors
familydata['Savings to Income'] = familydata['Savings']/familydata['Income']
familydata['Expense ratio'] = (familydata['Monthly Expenses']/familydata['Income'])*100
familydata['Loan ratio'] = (familydata['Loan Payments']/familydata['Income'])*100

# Add credit card spending trends
# Add cateogory based spending trends
# Provide scoring weights for each of these factors and convert into a working function to find human health (decide using which model and stuff)

# %%
familydata
# Out:
#     Family ID    Amount  Member Count  Income  Savings  Monthly Expenses  \
# 0      FAM001  23188.90             4  113810    20234              5781
# 1      FAM002  22309.71             5   44592    29492              5630
# 2      FAM003  11220.34             2   33278    11365              5282
# 3      FAM004  23483.10             5  127196    30735              3591
# 4      FAM005  40246.21             7   66048     1212              3136
# ..        ...       ...           ...     ...      ...               ...
# 195    FAM196  31433.34             7   64973     3604              3533
# 196    FAM197   4032.82             2  130741    41591              6463
# 197    FAM198  19378.59             4  114012     6372              4345
# 198    FAM199  31009.65             7   74587    28474              3672
# 199    FAM200  24887.93             6   44621    44081              4296
#
#      Loan Payments  Credit Card Spending  Financial Goals Met (%)  \
# 0             2422                  2959                       68
# 1             4541                   995                       60
# 2             1042                  2818                      100
# 3             1571                   668                       82
# 4             3444                  1922                       89
# ..             ...                   ...                      ...
# 195            622                   744                       26
# 196           4850                  1179                       62
# 197           1989                  1759                       51
# 198            834                  2937                       36
# 199           2470                  2831                       92
#
#      Savings to Income  Expense ratio  Loan ratio
# 0             0.177788       5.079518    2.128108
# 1             0.661374      12.625583   10.183441
# 2             0.341517      15.872348    3.131198
# 3             0.241635       2.823202    1.235102
# 4             0.018350       4.748062    5.214390
# ..                 ...            ...         ...
# 195           0.055469       5.437643    0.957321
# 196           0.318117       4.943361    3.709624
# 197           0.055889       3.811002    1.744553
# 198           0.381756       4.923110    1.118157
# 199           0.987898       9.627754    5.535510
#
# [200 rows x 12 columns]
